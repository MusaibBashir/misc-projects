# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pos_r=np.array([4.316,4.144,4.074,3.992,3.950,3.832,3.762,3.660,3.582,3.532,3.416,3.362,3.310,3.236,3.116,2.966,2.874,2.816,2.772,2.718,2.624,2.604,2.429,2.374,2.266,2.188,2.112,2.074,1.990])

# %%
theta_r=(pos_r-3.116)/(49.7)

# %%
theta_r=np.round(theta_r,4)
theta_r
# Out:
# array([ 0.0241,  0.0207,  0.0193,  0.0176,  0.0168,  0.0144,  0.013 ,
#         0.0109,  0.0094,  0.0084,  0.006 ,  0.0049,  0.0039,  0.0024,
#         0.    , -0.003 , -0.0049, -0.006 , -0.0069, -0.008 , -0.0099,
#        -0.0103, -0.0138, -0.0149, -0.0171, -0.0187, -0.0202, -0.021 ,
#        -0.0227])

# %%
I_r=np.array([0.20,0.33,0.49,0.69,0.77,0.65,0.43,0.23,0.66,1.13,4.15,6.64,8.05,10.48,12.73,10.96,8.16,5.58,2.58,1.19,0.72,0.24,0.46,0.58,0.72,0.59,0.41,0.32,0.21])

# %%
if(len(theta_r)==len(I_r)):
    print('yes')
# Out:
# yes

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(16,8))
sns.scatterplot(x=theta_r, y=I_r)
plt.xticks(np.arange(-0.025, 0.025, 0.0025))  
major_ticks = np.arange(0, 13, 1) 
plt.yticks(major_ticks)
plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(0.00025))
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
plt.grid(which='both', linestyle='--', linewidth=0.9)
plt.grid(which='minor', linestyle=':', linewidth=0.3)
plt.savefig("Single Slit.png", dpi=300)
plt.show()

# %%
pos_l=np.array([1.954,2.110,2.250,2.340,2.346,2.382,2.476,2.520,2.620,2.658,2.672,2.700,2.720,2.728,2.834,2.908,3.032,3.148,3.276,3.366,3.460,3.334,3.520,3.668,3.884,3.952,4.068,4.184,4.316])

# %%
theta_l=(pos_l-3.148)/(49.7)

# %%
theta_l=np.round(theta_l,4)
theta_l
# Out:
# array([-0.024 , -0.0209, -0.0181, -0.0163, -0.0161, -0.0154, -0.0135,
#        -0.0126, -0.0106, -0.0099, -0.0096, -0.009 , -0.0086, -0.0085,
#        -0.0063, -0.0048, -0.0023,  0.    ,  0.0026,  0.0044,  0.0063,
#         0.0037,  0.0075,  0.0105,  0.0148,  0.0162,  0.0185,  0.0208,
#         0.0235])

# %%
I_l=np.array([0.21,0.32,0.57,0.65,0.72,0.50,0.40,0.27,0.35,0.64,0.88,1.16,1.62,3.06,5.77,7.29,11.33,12.71,10.55,7.60,4.06,2.10,1.19,0.26,0.51,0.74,0.61,0.32,0.20])

# %%
if(len(theta_l)==len(I_l)):
    print('yes')
# Out:
# yes

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=theta_r, y=I_r)
plt.xticks(np.arange(-0.025, 0.025, 0.005))  
major_ticks = np.arange(0, 13, 1) 
plt.yticks(major_ticks)
plt.minorticks_on()
plt.gca().yaxis.set_minor_locator(ticker.MultipleLocator(0.1))
plt.gca().xaxis.set_minor_locator(ticker.MultipleLocator(0.0005))
plt.grid(which='both', linestyle='--', linewidth=0.5)
plt.grid(which='minor', linestyle=':', linewidth=0.3)
plt.savefig("Single Slit_left.png", dpi=300)
plt.show()
